# %% [markdown]
# # Importing all the dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Load the dataset
data = pd.read_csv("creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Statistical measures
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %% [markdown]
# # Highly unbalanced data
#
# ## 0 --> Normal Transaction
# ## 1 --> Fraudlent Transaction

# %%
# separating data for analysis
legit = data[data.Class==0]
fraud = data[data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
# Statistical measures of the data
print('Legit data: \n', legit.Amount.describe())
print('\nFraud data: \n', fraud.Amount.describe())
# Out:
# Legit data:
#  count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64
#
# Fraud data:
#  count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Compare the values for both Transactions
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# Build sample dataset contaning similar distribution of Normal transaction and fraud transaction=492
legit_sample= legit.sample(n= 492)

# %%
# concatenate two dataframes
new_data=pd.concat([legit_sample, fraud], axis=0)
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 78179    57403.0 -0.542779  0.920622  0.909481  0.925287  0.950028  0.893069
# 141142   84144.0  1.327446  0.390071 -0.097687  0.448717  0.196443 -0.476318
# 221675  142655.0 -0.178071 -0.892537  0.913884 -1.767892  0.082700 -0.064757
# 139433   83152.0  1.294294  0.484692 -0.796779  0.529648  0.462850 -0.627822
# 176695  122873.0 -0.675410  1.565313 -0.868554  0.583249  1.099171  0.174264
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 78179   0.779557 -0.086773  0.149843  ... -0.168314  0.014938 -0.280853
# 141142  0.124656 -0.188922 -0.030493  ... -0.343652 -0.944029 -0.005713
# 221675 -0.895612  0.268917 -0.678263  ...  0.457235  1.022410  0.164815
# 139433  0.235367 -0.083784 -0.272175  ... -0.147582 -0.430224 -0.186692
# 176695  0.798901  0.491207 -0.701613  ...  0.113001  0.480681 -0.290384
#
# ...

# %%
new_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94448.538618  0.181644 -0.066630 -0.007671 -0.093036 -0.105683
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.054147  0.061326 -0.052542 -0.017534  ...  0.004331  0.028067
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.035006  0.008663  0.007421 -0.005215 -0.007604  0.007746 -0.021029
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0      100.801199
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# Data preprocessing
# Scale all features except 'Time' and 'Class'
scaler = StandardScaler()
new_data.iloc[:, 1:-1] = scaler.fit_transform(new_data.iloc[:, 1:-1])

# %% [markdown]
# # Spliting data into features and Target

# %%
#Split the data into training and testing sets
X=new_data.drop(['Time', 'Class'], axis=1)
y=new_data['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 29) (787, 29) (197, 29)

# %%
# Model training - Logistic Regression
logistic_regression = LogisticRegression(max_iter=1000, random_state=42)
logistic_regression.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
# Accuracy on Training data
X_train_prediction = logistic_regression.predict(X_train)
training_data_accuracy = accuracy_score(y_train, X_train_prediction)
print('Accuracy on Training data:', training_data_accuracy)
# Out:
# Accuracy on Training data: 0.9440914866581956

# %%
# Accuracy on test data
X_test_prediction = logistic_regression.predict(X_test) 
test_data_accuracy = accuracy_score(y_test, X_test_prediction)
print('Accuracy on Test data:', test_data_accuracy)
# Out:
# Accuracy on Test data: 0.9644670050761421

# %%
# Create a bar chart
plt.figure(figsize=(6, 4))
plt.bar(['Test Data'], [test_data_accuracy], color='blue')
plt.xlabel('Dataset')
plt.ylabel('Accuracy')
plt.title('Accuracy on Test Data')
plt.ylim(0, 1)  # Set the y-axis range from 0 to 1 for accuracy
plt.show()
